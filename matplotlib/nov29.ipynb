# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.7.5'

# %%
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
x=[5,2,7]
y=[1,10,4]
plt.plot(x,y)
plt.title('Line Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.title('Line Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'ro')
plt.axis([0,6,0,26])
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'b')
plt.axis([0,6,0,26])
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'-g')
plt.axis([0,6,0,26])
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'--')
plt.axis([0,6,0,26])
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],'^k')
plt.axis([0,6,0,26])
plt.show()

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25],marker='o')
plt.axis([0,6,0,26])
plt.show()

# %%
import numpy as np

x = np.random.normal(size=1000)

plt.hist(x,bins=10)
plt.show()

# %%
import numpy as np

x = np.random.randint(5,100,50)

plt.hist(x,bins=10)
plt.show() 
print(x)
# Out:
# [22 90 82 77 90 82 61 86 20 46 39 41 21 29 84 29 14 46 26 41 74 25 66 95
#  71 48 69 12 33 27 30 38 39 93 60 48 20 79 89 41 55 13 19 79 47  5 37 82
#  31  7]

# %%
labels = ['apples','banana','orange']
sizes=[30,40,20]
plt.pie(sizes, labels=labels)
plt.show()
