# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Project\Dataset\product_sales.csv')

# %%
df
# Out:
#            Date Customer Type                   Country  Product
# 0     1/12/2023    Government                   Germany   SR1001  \
# 1     1/12/2023     Education  United States of America  RR10020
# 2     1/12/2023    Government                    Canada  FR10021
# 3     1/12/2023    Government                   Germany  FR10021
# 4     1/12/2023    Government                    Canada   HY1004
# ...         ...           ...                       ...      ...
# 1041   1/1/2022       Creator                    Canada   AR1200
# 1042   1/1/2022    Government                   Germany   SR1001
# 1043   1/1/2022     Education                   Germany  PS10022
# 1044   1/1/2022    Enterprise                    France   SR1001
# 1045   1/1/2022     Education                    Canada  FR10021
#
#       Discount Band   Units Sold
# 0              None           15
# 1              None            6
# 2              None           18
# 3              None           15
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y").dt.strftime("%Y/%m/%d")

# %%
df
# Out:
#             Date Customer Type                   Country  Product
# 0     2023/12/01    Government                   Germany   SR1001  \
# 1     2023/12/01     Education  United States of America  RR10020
# 2     2023/12/01    Government                    Canada  FR10021
# 3     2023/12/01    Government                   Germany  FR10021
# 4     2023/12/01    Government                    Canada   HY1004
# ...          ...           ...                       ...      ...
# 1041  2022/01/01       Creator                    Canada   AR1200
# 1042  2022/01/01    Government                   Germany   SR1001
# 1043  2022/01/01     Education                   Germany  PS10022
# 1044  2022/01/01    Enterprise                    France   SR1001
# 1045  2022/01/01     Education                    Canada  FR10021
#
#       Discount Band   Units Sold
# 0              None           15
# 1              None            6
# 2              None           18
# 3              None           15
# ...

# %%
df.to_csv("product_sales4.csv", index=False)
