# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#boxplot

df = pd.read_csv('D:\\Python Libraries\\tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(df['tip'])
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.show()

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='box')

# %%
0.3-0.2
# Out:
# 0.09999999999999998

# %%
0.1!=(0.3-0.2)
# Out:
# True

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='box',hue='sex')

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='violin',hue='sex')

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='violin',hue='sex')
plt.show()

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='violin',hue='sex',split=True)
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=df)
plt.show()

# %%
sns.catplot(x="day", y="total_bill", data=df,kind='bar',hue='sex')
plt.show()
