# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Python Libraries\ds_salaries.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type
# 0             0       2020               MI              FT  \
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd
# 0                Data Scientist   70000             EUR          79833  \
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
#find the number of unique job titles
df['job_title'].nunique()
# Out:
# 50

# %%
#find the number of data scientist in the dataset
df[df['job_title']== 'Data Scientist'].count()
# Out:
# Unnamed: 0            143
# work_year             143
# experience_level      143
# employment_type       143
# job_title             143
# salary                143
# salary_currency       143
# salary_in_usd         143
# employee_residence    143
# remote_ratio          143
# company_location      143
# company_size          143
# dtype: int64

# %%
#salarie of each group
df.groupby('job_title').groups
# Out:
# {'3D Computer Vision Researcher': [77], 'AI Scientist': [52, 96, 113, 244, 277, 391, 606], 'Analytics Engineer': [344, 368, 560, 561], 'Applied Data Scientist': [82, 123, 509, 519, 525], 'Applied Machine Learning Scientist': [132, 157, 489, 506], 'BI Data Analyst': [23, 73, 76, 102, 168, 196], 'Big Data Architect': [255], 'Big Data Engineer': [2, 17, 31, 120, 180, 192, 213, 230], 'Business Data Analyst': [8, 28, 279, 458, 511], 'Cloud Data Engineer': [95, 149], 'Computer Vision Engineer': [54, 133, 216, 271, 454, 521], 'Computer Vision Software Engineer': [98, 99, 510], 'Data Analyst': [5, 14, 15, 34, 38, 50, 51, 79, 86, 89, 100, 103, 105, 118, 122, 124, 135, 140, 172, 229, 233, 241, 254, 261, 290, 291, 296, 297, 305, 306, 307, 308, 318, 325, 326, 327, 328, 329, 330, 331, 332, 333, 336, 338, 339, 349, 360, 361, 362, 363, 367, 376, 382, 383, 387, 392, 393, 402, 403, 406, 408, 429, 430, 431, 440, 441, 470, 471, 522, 527, 528, 529, 530, 531, 536, 540, 541, 548, 564, 566, 567, 568, 572, 
# ...

# %%
df.groupby('job_title').max('salary')
# Out:
#                                           Unnamed: 0  work_year    salary
# job_title
# 3D Computer Vision Researcher                     77       2021    400000  \
# AI Scientist                                     606       2022   1335000
# Analytics Engineer                               561       2022    205300
# Applied Data Scientist                           525       2022    380000
# Applied Machine Learning Scientist               506       2022    423000
# BI Data Analyst                                  196       2021  11000000
# Big Data Architect                               255       2021    125000
# Big Data Engineer                                230       2021   1672000
# Business Data Analyst                            511       2022   1400000
# Cloud Data Engineer                              149       2021    160000
# Computer Vision Engineer                         521       2022    180000
# ...

# %%
df.groupby('job_title').sum('salary')
# Out:
#                                           Unnamed: 0  work_year    salary
# job_title
# 3D Computer Vision Researcher                     77       2021    400000  \
# AI Scientist                                    1779      14148   2034000
# Analytics Engineer                              1833       8088    700000
# Applied Data Scientist                          1758      10108    862000
# Applied Machine Learning Scientist              1284       8086    565400
# BI Data Analyst                                  638      12125  11412272
# Big Data Architect                               255       2021    125000
# Big Data Engineer                                985      16165   3640000
# Business Data Analyst                           1284      10105   1775000
# Cloud Data Engineer                              244       4042    280000
# Computer Vision Engineer                        1649      12127    501000
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
pd.date_range('1/1/2011',periods=13)
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08',
#                '2011-01-09', '2011-01-10', '2011-01-11', '2011-01-12',
#                '2011-01-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('1/1/2011',periods=13,freq='M')
# Out:
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31',
#                '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31',
#                '2012-01-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.bdate_range('1/1/2011',periods=13)
# Out:
# DatetimeIndex(['2011-01-03', '2011-01-04', '2011-01-05', '2011-01-06',
#                '2011-01-07', '2011-01-10', '2011-01-11', '2011-01-12',
#                '2011-01-13', '2011-01-14', '2011-01-17', '2011-01-18',
#                '2011-01-19'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('1/1/2011',periods=13,freq='Y')
# Out:
# DatetimeIndex(['2011-12-31', '2012-12-31', '2013-12-31', '2014-12-31',
#                '2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31',
#                '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31',
#                '2023-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.to_datetime('2011-1-1')
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
df1=pd.DataFrame({'name':['a','b','c'],'salary':[12,13,14]})
df2=pd.DataFrame({'name':['a','d','c'],'age':[12,13,14]})

# %%
df1
# Out:
#   name  salary
# 0    a      12
# 1    b      13
# 2    c      14

# %%
df2
# Out:
#   name  age
# 0    a   12
# 1    d   13
# 2    c   14

# %%
pd.merge(df1,df2,on='name')
# Out:
#   name  salary  age
# 0    a      12   12
# 1    c      14   14

# %%
pd.merge(df1,df2,on='name',how='inner')
# Out:
#   name  salary  age
# 0    a      12   12
# 1    c      14   14

# %%
pd.merge(df1,df2,on='name',how='outer')
# Out:
#   name  salary   age
# 0    a    12.0  12.0
# 1    b    13.0   NaN
# 2    c    14.0  14.0
# 3    d     NaN  13.0

# %%
pd.merge(df1,df2,on='name',how='left')
# Out:
#   name  salary   age
# 0    a      12  12.0
# 1    b      13   NaN
# 2    c      14  14.0

# %%
pd.merge(df1,df2,on='name',how='right')
# Out:
#   name  salary  age
# 0    a    12.0   12
# 1    d     NaN   13
# 2    c    14.0   14

# %%
pd.merge(df1,df2,left_on='salary',right_on='age')
# Out:
#   name_x  salary name_y  age
# 0      a      12      a   12
# 1      b      13      d   13
# 2      c      14      c   14

# %%
pd.merge(df1,df2,left_on='name',right_on='name',how='inner')
# Out:
#   name  salary  age
# 0    a      12   12
# 1    c      14   14

# %%
df1.merge(df2,left_on='name',right_on='name')
# Out:
#   name  salary_x  salary_y
# 0    a        12        12
# 1    c        14        14

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type
# 0             0       2020               MI              FT  \
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd
# 0                Data Scientist   70000             EUR          79833  \
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df[df['work_year'].apply(lambda x: str(x)[2:] == '20')]
# Out:
#     Unnamed: 0  work_year experience_level employment_type
# 0            0       2020               MI              FT  \
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# ..         ...        ...              ...             ...
# 67          67       2020               SE              FT
# 68          68       2020               EN              FT
# 69          69       2020               SE              FT
# 70          70       2020               MI              FT
# 71          71       2020               MI              FT
#
#                      job_title  salary salary_currency  salary_in_usd
# 0               Data Scientist   70000             EUR          79833  \
# 1   Machine Learning Scientist  260000             USD         260000
# ...

# %%
df[df['work_year'].apply(lambda exp: str(exp)[2:]=='21')]
# Out:
#      Unnamed: 0  work_year experience_level employment_type
# 72           72       2021               EN              FT  \
# 73           73       2021               EX              FT
# 74           74       2021               EX              FT
# 75           75       2021               SE              FT
# 76           76       2021               MI              FT
# ..          ...        ...              ...             ...
# 284         284       2021               MI              FT
# 285         285       2021               SE              FT
# 286         286       2021               SE              FT
# 287         287       2021               MI              FT
# 288         288       2021               MI              FT
#
#                      job_title   salary salary_currency  salary_in_usd
# 72          Research Scientist    60000             GBP          82528  \
# 73             BI Data Analyst   150000             USD         150000
# ...

# %%
df['work_year'].apply(lambda exp: str(exp)[2:]=='21').sum()
# Out:
# 217

# %%
df['work_year'].apply(lambda exp: str(exp)[2:]=='21').count()
# Out:
# 607
