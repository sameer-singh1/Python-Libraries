# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Python Libraries\imdb_data.csv')

# %%
df
# Out:
#         id                              belongs_to_collection    budget
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres
# ...

# %%
#write a python pandas program to get the columns of the dataframe
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
#write a program to get the information of the datasets
df.info
# Out:
# <bound method DataFrame.info of         id                              belongs_to_collection    budget
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         id                              belongs_to_collection    budget
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres
# ...

# %%
#write a pandas program to get the detail of fourth movie
df.iloc[3]
# Out:
# id                                                                       4
# belongs_to_collection                                                  NaN
# budget                                                             1200000
# genres                   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# homepage                                        http://kahaanithefilm.com/
# imdb_id                                                          tt1821480
# original_language                                                       hi
# original_title                                                     Kahaani
# overview                 Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# popularity                                                        3.174936
# poster_path                               /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# production_companies                                                   NaN
# ...

# %%
#write a pandas program to count the number of row and column of the dataframe
df.shape
# Out:
# (3000, 23)

# %%
#write a pandas program to get the details of the column budget and title
df[['budget','title']]
# Out:
#         budget                                     title
# 0     14000000                    Hot Tub Time Machine 2
# 1     40000000  The Princess Diaries 2: Royal Engagement
# 2      3300000                                  Whiplash
# 3      1200000                                   Kahaani
# 4            0                                Marine Boy
# ...        ...                                       ...
# 2995         0                                   Chasers
# 2996         0                          We Are the Best!
# 2997  65000000                   The Long Kiss Goodnight
# 2998  42000000                          Along Came Polly
# 2999  35000000                                 Abduction
#
# [3000 rows x 2 columns]

# %%
#write a pandas program to get the details of the movie with the name 'Grumpier Old Man'

df[df['title']=='Kahaani']
# Out:
#    id belongs_to_collection   budget
# 3   4                   NaN  1200000  \
#
#                                               genres
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  \
#
#                      homepage    imdb_id original_language original_title
# 3  http://kahaanithefilm.com/  tt1821480                hi        Kahaani  \
#
#                                             overview  popularity  ... runtime
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...   122.0  \
#
#                                     spoken_languages    status tagline
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released     NaN  \
#
#      title                                           Keywords
# 3  Kahaani  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...  \
#
#                                                 cast
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...  \
#
#                                                 crew   revenue
# ...

# %%
#write a pandas program to sort the imdb dataset based on budget
df.sort_values('budget')
# Out:
#         id                              belongs_to_collection     budget
# 895    896                                                NaN          0  \
# 594    595                                                NaN          0
# 595    596                                                NaN          0
# 1252  1253                                                NaN          0
# 2144  2145                                                NaN          0
# ...    ...                                                ...        ...
# 1630  1631  [{'id': 8650, 'name': 'Transformers Collection...  260000000
# 1425  1426  [{'id': 8537, 'name': 'Superman Collection', '...  270000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2209  2210  [{'id': 295, 'name': 'Pirates of the Caribbean...  300000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
#
#                                                  genres
# ...
